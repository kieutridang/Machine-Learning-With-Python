# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)

# %cd '/content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter12_HierarchicalClustering'
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter12_HierarchicalClustering

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np

# %%
X = np.array([[5,3],  
    [10,15],
    [15,12],
    [24,10],
    [85, 90],         
    [30,30],
    [85,70],
    [71,80],
    [60,78],
    [70,55],
    [80,91],])

# %%
import scipy.cluster.hierarchy as sch

plt.figure(figsize= (10, 3))
plt.title("Dendograms")
dend = sch.dendrogram(sch.linkage(X, method = 'ward'))

# %%
# cluster = 2
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters = 2,
                                  affinity = 'euclidean')
cluster.fit(X)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=2)

# %%
print(cluster.labels_)
# Out:
# [1 1 1 1 0 1 0 0 0 0 0]

# %%
X_test = np.array([[65, 75], [75, 85]])
y_test = cluster.predict(X_test)
plt.scatter(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f5cfcf289d52> in <module>()
#       1 X_test = np.array([[65, 75], [75, 85]])
# ----> 2 y_test = cluster.predict(X_test)
#       3 plt.scatter(X_test, y_test)
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'predict'
