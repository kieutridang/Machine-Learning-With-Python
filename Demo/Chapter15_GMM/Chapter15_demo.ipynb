# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)

# %cd '/content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter15_GMM'
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter15_GMM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
import seaborn as sns

# %%
X_train = np.load('data.npy')

# %%
X_train[0]
# Out:
# array([2.61755903, 2.49389168])

# %%
X_train.size
# Out:
# 400

# %%
plt.figure(figsize = (6,6))
plt.plot(X_train[:, 0], X_train[:, 1], 'bx')
plt.axis('equal')
plt.show()
# Nhận xét: Dữ liệu ko phân cụm rõ ràng
# => Dùng GMM để thực hiện việc phân cụm

# %%
sns.kdeplot(data=X_train[:, 0], y=X_train[:, 1])
