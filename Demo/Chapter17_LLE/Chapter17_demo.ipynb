# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)

# %cd '/content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter17_LLE'
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive/LDS6_S7CN_KieuTriDang/Demo/Chapter17_LLE

# %% [markdown]
# # Prepare libraries and data

# %% [markdown]
# ## Import libraries

# %%
from sklearn.datasets import make_swiss_roll

# %% [markdown]
# ## Prepare data

# %%
X, y = make_swiss_roll(n_samples=1000,
                       noise=0.2,
                       random_state=41)

# %%
X
# Out:
# array([[  5.27336593,   0.17908113,   4.83303567],
#        [  2.03125563,   4.16459399,  -4.68255974],
#        [  0.85309232,  20.90012948, -11.15183668],
#        ...,
#        [  6.60249152,   0.50710576,  12.30210256],
#        [  5.90783552,  13.09870753,  -1.0956307 ],
#        [ 10.4320605 ,   9.29453856,   8.55622118]])

# %%
y
# Out:
# array([ 7.07728842,  5.14683186, 11.09123177,  5.12207923,  5.80965653,
#        10.40368902,  6.51186808, 11.01300118, 13.35913125,  8.65929831,
#         7.84386429,  7.37991815,  6.46805799,  7.70108475,  9.24729685,
#         5.36760395, 11.35669318,  7.67814921, 11.73650969,  8.46545616,
#        10.44478831, 11.57792963,  8.68736484,  8.42488643,  6.90103518,
#         8.87497981,  8.2280328 , 10.21274632,  5.65516248, 11.69946589,
#         5.49651101,  5.90202163,  7.75556996, 10.77183596, 14.13218811,
#         7.36076715, 10.19972701, 12.93646022, 12.15173585,  6.76781707,
#         7.9792256 , 11.51237233,  8.04799107,  9.05423626,  7.01578265,
#         7.37642694, 12.49990833, 12.95314845,  6.05795512,  7.35200377,
#         9.66199158, 13.20277527, 10.39041192, 11.23240975,  7.37578329,
#         7.31841058,  6.18536005, 10.96844735, 13.59814952, 11.13369277,
#        12.84580966, 13.30313621, 12.39679199, 12.53257836,  4.96777266,
# ...

# %% [markdown]
# ## Visualize swiss roll orignal

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
fig = plt.figure(figsize=(16,13))
ax = fig.add_subplot(2, 2, 1, projection = '3d')
ax.scatter(X[:, 0],
           X[:, 1],
           X[:, 2],
           c = y,
           cmap = plt.cm.hsv)
ax.view_init(10, -66)
ax.set_xlabel('$x_1$', fontsize = 18)
ax.set_ylabel('$x_2$', fontsize = 18)
ax.set_zlabel('$x_3$', fontsize = 18)
ax.set_title("Swiss Roll Data", fontsize = 22)
# Out:
# Text(0.5, 0.92, 'Swiss Roll Data')

# %% [markdown]
# ## Locally Linear Embedding

# %%
from sklearn.manifold import LocallyLinearEmbedding

lle = LocallyLinearEmbedding(n_components = 2,
                             n_neighbors = 10,
                             random_state = 42)
X_reduced = lle.fit_transform(X)
X_reduced
# Out:
# array([[-0.02911278,  0.05697208],
#        [-0.04602962,  0.06451161],
#        [ 0.01954969, -0.02684515],
#        ...,
#        [ 0.04923591,  0.03083726],
#        [-0.03589353, -0.0166996 ],
#        [ 0.04740873,  0.01104797]])

# %%
# After feature reduction
plt.title("Swiss Roll Data after applying LLE",
          fontsize = 22)
plt.scatter(X_reduced[:, 0],
            X_reduced[:, 1],
            c = y,
            cmap = plt.cm.hsv)
plt.xlabel("$z_1$", fontsize = 18)
plt.ylabel("$z_2$", fontsize = 18)
plt.grid(True)
plt.show()
